# %% [markdown]
# <a href="https://colab.research.google.com/github/MohanKumar242/IAM-Tasks/blob/main/TASK_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Objective

Use Burp Suite to bypass authentication.
Gain administrator rights by accessing and modifying server-side scripts.
Change a user's password to escalate privileges.

Lab Requirements
Tools: Kali Linux (or any system with Burp Suite), a vulnerable web application (e.g., OWASP Juice Shop or DVWA), and an active browser.
Setup: Ensure the vulnerable web application is running on a local server or sandboxed environment.
Prerequisites: Basic understanding of web application vulnerabilities, HTTP requests, and Burp Suite.

Part 1: Setting Up Burp Suite
Start Burp Suite

Open Burp Suite from your Kali Linux environment:
bash
Copy code
burpsuite
Configure Proxy

Set up Burp Suite's proxy listener:
Go to Proxy > Options and ensure the proxy is running on 127.0.0.1:8080.
Configure Browser

Set your browser to use Burp Suite as a proxy:
In browser settings, configure the proxy as 127.0.0.1:8080.
Enable Intercept

Enable request interception in Burp Suite under Proxy > Intercept.

Part 2: Authentication Bypass

Intercept Login Request

Visit the login page of the vulnerable application.
Enter dummy credentials (e.g., admin:test) and submit. Burp Suite will capture the request.
Modify the Request

Analyze the captured HTTP request in Burp Suite. Look for parameters such as username and password.
Try modifying or injecting malicious inputs, such as:
SQL Injection: Replace username=admin and password=test with:
sql
Copy code
username=admin' OR '1'='1
password=anypassword
Null Bypass: Replace username=admin and password=test with:
plaintext
Copy code
username=admin--
password=
Forward the Request

Click Forward in Burp Suite to send the modified request to the server.
Verify Bypass

If successful, you should be logged in as the administrator or the targeted user.

Part 3: Accessing Server-Side Script

Find Vulnerable Endpoints

Use Burp Suite's Spider tool to crawl the application and locate sensitive endpoints or server-side scripts (e.g., /admin, /config.php, /reset-password).
Manipulate Parameters

Intercept and modify HTTP parameters in requests to gain unauthorized access:
Change user_role=user to user_role=admin.
Access hidden endpoints directly by navigating to them (e.g., /admin_panel).
Access Server-Side Script

If the server is vulnerable, you may access configuration files or scripts containing sensitive data (e.g., database credentials, admin functions).

Part 4: Changing Password and Privilege Escalation

Locate Password Reset Feature

Intercept the request for the password reset functionality using Burp Suite.
Modify the username parameter to the administrator's username:
plaintext
Copy code
username=admin
Set a New Password

If the server allows it, submit a new password (e.g., new_password123) for the admin account.
Log In with New Credentials

Use the updated credentials (admin:new_password123) to log in and access the server-side application.

Part 5: Verification and Auditing

Verify Admin Access

Confirm that you have administrator rights by checking for additional privileges or functionalities (e.g., user management, sensitive data access).
Audit Logs

Check server logs (if accessible) to understand the bypass flow and identify potential fixes.
Recommendations
Implement Security Best Practices:
Validate and sanitize all user inputs to prevent injection attacks.
Use secure password reset mechanisms with token-based authentication.
Monitor Logs:
Continuously monitor logs for suspicious activity.
Update Software:
Regularly update applications and server software to fix known vulnerabilities.
Cleanup
Disable or shut down the vulnerable application and remove any test accounts or scripts used during the lab.
Conclusion:This lab demonstrated the process of exploiting vulnerabilities in web applications using Burp Suite to gain unauthorized access, escalate privileges, and compromise server-side functionalities.
